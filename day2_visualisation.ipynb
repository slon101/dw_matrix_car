# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cd "/content/drive/My Drive/Colab Notebooks/matrix/matrix_two/dw_matrix_car"
# Out:
# /content/drive/My Drive/Colab Notebooks/matrix/matrix_two/dw_matrix_car

# %%
df = pd.read_hdf('data/car.h5')
df.shape
# Out:
# (106494, 155)

# %%
ls
# Out:
# dw_matrix_car/

# %%
cd sample_data/
ls
# Out:
#   File "<ipython-input-6-714b1f77e3fc>", line 1
#     cd sample_data/
#                  ^
# SyntaxError: invalid syntax

# %%
# !pwd
# Out:
# /content

# %%
# !pip install --upgrade tables
# Out:
# Collecting tables
#   Downloading https://files.pythonhosted.org/packages/ed/c3/8fd9e3bb21872f9d69eb93b3014c86479864cca94e625fd03713ccacec80/tables-3.6.1-cp36-cp36m-manylinux1_x86_64.whl (4.3MB)
#      |████████████████████████████████| 4.3MB 2.9MB/s
# Requirement already satisfied, skipping upgrade: numpy>=1.9.3 in /usr/local/lib/python3.6/dist-packages (from tables) (1.17.5)
# Requirement already satisfied, skipping upgrade: numexpr>=2.6.2 in /usr/local/lib/python3.6/dist-packages (from tables) (2.7.1)
# Installing collected packages: tables
#   Found existing installation: tables 3.4.4
#     Uninstalling tables-3.4.4:
#       Successfully uninstalled tables-3.4.4
# Successfully installed tables-3.6.1

# %%
# !pwd
# Out:
# /content/drive/My Drive/Colab Notebooks/matrix/matrix_two/dw_matrix_car

# %%
df['price_value'].hist(bins=100)

# %%
df['price_value'].describe()
# Out:
# count    106494.000000
# mean      47534.137437
# std       66308.716918
# min         400.000000
# 25%       13890.000000
# 50%       25500.000000
# 75%       52900.000000
# max      799900.000000
# Name: price_value, dtype: float64

# %%
def group_and_barplot(feat_groupby, feat_agg='price_value', agg_funcs=[np.mean, np.median, np.size], feat_sort='mean', top=50, subplots=True):
  return (
      df
      .groupby(feat_groupby)[feat_agg]
      .agg(agg_funcs)
      .sort_values(by=feat_sort, ascending=False)
      .head(top)
      ).plot(kind='bar', figsize=(15, 5),subplots=subplots)

# %%
group_and_barplot('param_marka-pojazdu')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f5d4f6ee7f0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f5d4f6ac8d0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f5d4f654898>],
#       dtype=object)

# %%
group_and_barplot('param_kraj-pochodzenia')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f5d50769b00>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f5d5088fa90>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f5d4f73ab38>],
#       dtype=object)

# %%
group_and_barplot('param_kolor',feat_sort='mean')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f5d4eff82b0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f5d4ef86d30>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f5d4efb3cf8>],
#       dtype=object)

# %%
# !git config --global user.email "bargatroll@gmail.com"
# !git config --global user.name "betanot"

# %%
# !pwd
# Out:
# /content/drive/My Drive/Colab Notebooks/matrix/matrix_two/dw_matrix_car

# %%
ls
